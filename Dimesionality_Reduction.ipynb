# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurpophale/data_science/blob/main/Dimesionality_Reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X,y = make_blobs(n_samples=500, n_features=5,centers=3,cluster_std=1.5, random_state=0)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.8347382 , -1.79532804,  0.88822828,  0.31462876,  0.45921857],
#        [ 0.98590006,  1.16069648, -0.71841975,  0.65251573, -0.76782845],
#        [-0.84241848, -0.86544427,  1.38847193,  0.55451943,  0.63356787],
#        ...,
#        [-0.4427929 ,  1.45755686, -0.7601097 , -1.31555048,  0.97410975],
#        [-1.18846666,  1.206506  , -1.05967404, -0.65449957,  1.24079209],
#        [-0.59107866,  0.63135756, -0.40919261, -1.29870281,  0.3068221 ]])

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca
# Out:
#           PC1       PC2
# 0    0.563526  1.806588
# 1    0.520236 -1.506674
# 2    0.245074  1.956492
# 3    1.484809 -0.751858
# 4   -2.869219  0.096109
# ..        ...       ...
# 495  1.588932 -2.110868
# 496 -2.583177 -0.785145
# 497 -2.184183 -0.637823
# 498 -2.214771 -0.285583
# 499 -1.525220 -0.385697
#
# [500 rows x 2 columns]

# %%
df_pca['labels'] = y

# %%
df_pca
# Out:
#           PC1       PC2  labels
# 0    0.563526  1.806588       1
# 1    0.520236 -1.506674       2
# 2    0.245074  1.956492       1
# 3    1.484809 -0.751858       2
# 4   -2.869219  0.096109       0
# ..        ...       ...     ...
# 495  1.588932 -2.110868       2
# 496 -2.583177 -0.785145       0
# 497 -2.184183 -0.637823       0
# 498 -2.214771 -0.285583       0
# 499 -1.525220 -0.385697       0
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='labels',palette='Set2')
#
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>
